# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is Gaurav Kumar,
#
# My current desire is to be an Data Scientist and My occupation is student

# %% [markdown]
# I am intrested in Data Sciene because as we know in today world data play an important role, and the future scope in data science and AI , i love python langauge and maths thats why i choose to learn data science

# %% [markdown]
# ###  It must be executed and must display an output

# %%
3+6
# Out:
# 9

# %% [markdown]
# 1) strikethrough= ~~ string ~~
#
# 2) italic = _italic_
#
# 3) bold = __bold__
#
# 4) line breaks = <br>
#
# 5) bullets = (-)
